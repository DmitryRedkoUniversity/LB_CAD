# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import numpy as np
import matplotlib.pyplot as plt

def custom_normal(N, sample_size):
    result = []

    for _ in range(sample_size):
        Ri = np.random.uniform(0, 1, N)  # Генерируем N случайных чисел из равномерного распределения [0, 1)
        xk = np.sqrt(12/N) * (np.sum(Ri) - N/2) 
        result.append(xk)

    return result

N = 10          # Размер выборки
sample_size = 100  # Увеличим размер сгенерированной выборки
samples = custom_normal(N, sample_size)

mean = np.mean(samples)
variance = np.var(samples)
std_deviation = np.sqrt(variance)

scaled_samples = (samples - mean) * (np.sqrt(np.sqrt(3)) / std_deviation)

scaled_mean = np.mean(scaled_samples)
scaled_variance = np.var(scaled_samples)

print("Среднее:", round(scaled_mean,3))
print("Дисперсия:", round(scaled_variance,3))

plt.hist(scaled_samples, bins=30, density=True, alpha=0.6, color='b', label='Выборка')
plt.xlabel('Значение')
plt.ylabel('Плотность')
plt.title('Гистограмма выборки с нормальным распределением (0, sqrt(3))')
plt.legend(loc='upper right')
plt.grid(True)

plt.show()
# Out:
# Среднее: 0.0
# Дисперсия: 1.732

# %%
import numpy as np
import matplotlib.pyplot as plt

def custom_normal(N, sample_size):
    result = []

    for _ in range(sample_size):
        Ri = np.random.uniform(0, 1, N)  # Генерируем N случайных чисел из равномерного распределения [0, 1)
        xk = np.sqrt(12/N) * (np.sum(Ri) - N/2) 
        result.append(xk)

    return result

# Параметры
N = 10          # Размер выборки
sample_size = 10000  # Увеличим размер сгенерированной выборки

samples = custom_normal(N, sample_size)

# Приведение к параметрам (0, sqrt(3))
mean = np.mean(samples)
variance = np.var(samples)
std_deviation = np.sqrt(variance)

scaled_samples = (samples - mean) * (np.sqrt(np.sqrt(3)) / std_deviation)

# Вывод среднего и дисперсии после приведения
scaled_mean = np.mean(scaled_samples)
scaled_variance = np.var(scaled_samples)

print("Среднее:", round(scaled_mean,3))
print("Дисперсия:", round(scaled_variance,3))

# Визуализация выборки
plt.hist(scaled_samples, bins=30, density=True, alpha=0.6, color='b', label='Выборка')
plt.xlabel('Значение')
plt.ylabel('Плотность')
plt.title('Гистограмма выборки с нормальным распределением (0, sqrt(3))')
plt.legend(loc='upper right')
plt.grid(True)

plt.show()
# Out:
# Среднее: 0.0
# Дисперсия: 1.732
